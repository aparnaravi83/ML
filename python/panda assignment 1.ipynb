# %%
pwd
# Out:
# 'C:\\datascience\\python'

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv",sep='\t')
df
# Out:
# The history saving thread hit an unexpected error (OperationalError('database or disk is full')).History will not be written to the database.
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
# ...

# %%
#Q1.print first 5 and last 7 records
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
df.tail(7)
# Out:
#       order_id  quantity            item_name  \
# 4615      1832         1   Chicken Soft Tacos
# 4616      1832         1  Chips and Guacamole
# 4617      1833         1        Steak Burrito
# 4618      1833         1        Steak Burrito
# 4619      1834         1   Chicken Salad Bowl
# 4620      1834         1   Chicken Salad Bowl
# 4621      1834         1   Chicken Salad Bowl
#
#                                      choice_description item_price
# 4615   [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]     $8.75
# 4616                                                NaN     $4.45
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75

# %%
#Q2.print total records and type of variables
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
df.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
#Q3.print the name of all the columns
df.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
#Q4.how is the dataset indexed
df.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
#Q5.which was the most ordered item and how many items were ordered
getitem=df.groupby('item_name')
df1=getitem.sum()
df1.sort_values('quantity',ascending=False).head(1)
# Out:
#               order_id  quantity
# item_name
# Chicken Bowl    713926       761

# %%
#Q6.what was the most ordered item in the choice_description column
getitem2=df.groupby('choice_description')
df2=getitem2.sum()
df2.sort_values('quantity',ascending=False).head(1)
# Out:
#                     order_id  quantity
# choice_description
# [Diet Coke]           123455       159

# %%
#Q7.turn the item price into a float
df.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
def itemprice(price):
    price=price[1:]
    return float(price)
df['PriceItems']=df['item_price'].apply(itemprice)
df.head()
df.dtypes
# Out:
# order_id                int64
# quantity                int64
# item_name              object
# choice_description     object
# item_price             object
# priceItems            float64
# PriceItems            float64
# dtype: object

# %%
#Q8 print a data frame with only two columns item_name and item_price
df[['item_name','item_price']]
# Out:
#                                   item_name item_price
# 0              Chips and Fresh Tomato Salsa     $2.39
# 1                                      Izze     $3.39
# 2                          Nantucket Nectar     $3.39
# 3     Chips and Tomatillo-Green Chili Salsa     $2.39
# 4                              Chicken Bowl    $16.98
# ...                                     ...        ...
# 4617                          Steak Burrito    $11.75
# 4618                          Steak Burrito    $11.75
# 4619                     Chicken Salad Bowl    $11.25
# 4620                     Chicken Salad Bowl     $8.75
# 4621                     Chicken Salad Bowl     $8.75
#
# [4622 rows x 2 columns]

# %%
#Q9.delete the duplicates in item_name and quantity
df.drop_duplicates(['quantity','item_name'])
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 3890      1559         2                  Carnitas Crispy Tacos
# 3973      1592         4                      Canned Soft Drink
# 4152      1660        10                          Bottled Water
# 4354      1738         2                       Steak Soft Tacos
# 4489      1786         4                    Chips and Guacamole
#
#                                      choice_description item_price  priceItems
# 0                                                   NaN     $2.39         2.39
# ...

# %%
#Q10.select only the products with quantity equals to 1
gb=df.groupby('quantity')
gb.get_group(1)[['item_name','quantity']]
# Out:
#                                   item_name  quantity
# 0              Chips and Fresh Tomato Salsa         1
# 1                                      Izze         1
# 2                          Nantucket Nectar         1
# 3     Chips and Tomatillo-Green Chili Salsa         1
# 5                              Chicken Bowl         1
# ...                                     ...       ...
# 4617                          Steak Burrito         1
# 4618                          Steak Burrito         1
# 4619                     Chicken Salad Bowl         1
# 4620                     Chicken Salad Bowl         1
# 4621                     Chicken Salad Bowl         1
#
# [4355 rows x 2 columns]

# %%
#Q11.select only the item_name and item_price columns
df[['item_name','item_price']]
# Out:
#                                   item_name item_price
# 0              Chips and Fresh Tomato Salsa     $2.39
# 1                                      Izze     $3.39
# 2                          Nantucket Nectar     $3.39
# 3     Chips and Tomatillo-Green Chili Salsa     $2.39
# 4                              Chicken Bowl    $16.98
# ...                                     ...        ...
# 4617                          Steak Burrito    $11.75
# 4618                          Steak Burrito    $11.75
# 4619                     Chicken Salad Bowl    $11.25
# 4620                     Chicken Salad Bowl     $8.75
# 4621                     Chicken Salad Bowl     $8.75
#
# [4622 rows x 2 columns]

# %%
#Q12.sort item from the most to less expensive
df4=df.sort_values('PriceItems',ascending=False)
df4[['item_name','PriceItems']]
# Out:
#                          item_name  PriceItems
# 3598  Chips and Fresh Tomato Salsa       44.25
# 3480                 Carnitas Bowl       35.25
# 1254               Chicken Burrito       35.00
# 3602               Chicken Burrito       35.00
# 3601                Veggie Burrito       33.75
# ...                            ...         ...
# 3936                   Canned Soda        1.09
# 2922                 Bottled Water        1.09
# 1396                   Canned Soda        1.09
# 2562                   Canned Soda        1.09
# 1457                   Canned Soda        1.09
#
# [4622 rows x 2 columns]

# %%
#Q13.what was the quantity of the most expensive item ordered
df4.head(1)[['quantity']]
# Out:
#       quantity
# 3598        15

# %%
#Q14.how many times were a veggie salad bowl ordered
df[df['item_name']=='Veggie Salad Bowl']['item_name'].count()

#or
# Out:
# 18

# %%
getitem=df.groupby('item_name')
d=getitem.get_group('Veggie Salad Bowl')[['quantity']]
d.sum()
# Out:
# quantity    18
# dtype: int64
